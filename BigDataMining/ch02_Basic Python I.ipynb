# %%
print("Hello World")
print('Hello World')
# Out:
# Hello World
# Hello World

# %%
print('Hello World')
# Out:
# Hello World

# %%
Print('Hello World')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_11250/2900866392.py in <cell line: 0>()
# ----> 1 Print('Hello World')
#
# NameError: name 'Print' is not defined

# %%
#print(2.3 + 5.2) # Not executed
print(2.3 + 5.2) # The print() command is executed; anything after '#' is ignored
# Write comments on multiple lines
# Out:
# 7.5

# %%
12+11
# Out:
# 23

# %%
2932839232923939 + 2382929292939393
# Out:
# 5315768525863332

# %%
2932839232923939 * 2382929292939393
# Out:
# 6988748519616353696655305829027

# %%
0.001 + 0.0001
# Out:
# 0.0011

# %%
0.001 * 0.00001
# Out:
# 1e-08

# %%
"""
To write
a string
across multiple lines,
enclose it in
triple quotation marks.
"""
# Out:
# '\nTo write\na string\nacross multiple lines,\nenclose it in\ntriple quotation marks.\n'

# %%
print("To display a backslash, use \\.")
print("First\tstatement\nNew statement")
print("\" in a string literal")
print('" in a string literal')
print('\' in a string literal')
print("' in a string literal")
# Out:
# To display a backslash, use \.
# First	statement
# New statement
# " in a string literal
# " in a string literal
# ' in a string literal
# ' in a string literal

# %%
2>3
# Out:
# False

# %%
2<3
# Out:
# True

# %%
x = 15
y = x + 12
print(y)
# Out:
# 27

# %%
a = 5        # Create a variable named a
b = "hello"  # Create a variable named b
print(a)
print(b)
# Out:
# 5
# hello

# %%
a = 3     # Attach the label a to a new memory location.
b = "hello2"  # Attach the label b to a new memory location.
print(a)
print(b)
# Out:
# 3
# hello2

# %%
a = "hello2"  # Attach the label a to the existing "hello2" object.
print(a)
print(b)
# Out:
# hello2
# hello2

# %%
a = 5  #Attach a to the existing 5 object.
print(a)
print(b)
# Out:
# 5
# hello2

# %%
c = b     # Create c and attach it to the same object referenced by b.

# %%
two = deux = zwei = 2
print(two,deux, zwei)
# Out:
# 2 2 2

# %%
user_name = None   # A variable is initialized with no value (None).
user_name = input("name: ") # Then, receive user input and assign it to the variable.
# Out:
# name: kbu

# %%
5 + 7.4
# Out:
# 12.4

# %%
print("hi")
# Out:
# hi

# %%
print(2+5.2)
# Out:
# 7.2

# %%
print(2-5.2)
# Out:
# -3.2

# %%
print(2*5.2)
# Out:
# 10.4

# %%
print(103.2/24)
# Out:
# 4.3

# %%
print(103.2//24)
# Out:
# 4.0

# %%
print(103.2%24)
# Out:
# 7.200000000000003

# %%
print(2**2.5)
# Out:
# 5.656854249492381

# %%
2 + 3 * 4 ** 2
# Out:
# 50

# %%
((2 + 3) * 4) ** 2
# Out:
# 400

# %%
"ABC" + "abc"
# Out:
# 'ABCabc'

# %%
"ABC" * 3
# Out:
# 'ABCABCABC'
